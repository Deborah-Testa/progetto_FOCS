# %% [markdown]
# ##### Progetto FOCS

# %% [markdown]
# You have to work on the [University dataset](https://drive.google.com/drive/folders/1Hs3nRtK_F3h8eg59B4-TD1DEua6g8Klv). It contains three different university rankings:
# - The Times Higher Education World University Ranking, shortly *Times*,
# - the Academic Ranking of World Universities, shortly *Shanghai*,
# - the Center for World University Rankings, shortly *cwur*.
#
# Notes
# 1. It is mandatory to use GitHub for developing the project.
# 2. The project must be a jupyter notebook.
# 3. There is no restriction on the libraries that can be used, nor on the Python version.
# 4. All questions on the project **must** be asked in a public channel on [Zulip](https://focs.zulipchat.com).

# %%
import pandas as pd
import re
import numpy as np

# %%
data_folder = "Data/"
times = pd.read_csv(f'{data_folder}timesData.csv', thousands=',')
times.head()
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching international  research  citations income total_score  \
# 0      99.7          72.4      98.7       98.8   34.5        96.1
# 1      97.7          54.6      98.0       99.9   83.7        96.0
# 2      97.8          82.3      91.4       99.9   87.5        95.6
# 3      98.3          29.5      98.1       99.2   64.3        94.3
# 4      90.9          70.3      95.4       99.9      -        94.2
#
#    num_students  student_staff_ratio international_students female_male_ratio  \
# 0       20152.0                  8.9                    25%               NaN
# 1        2243.0                  6.9                    27%           33 : 67
# 2       11074.0                  9.0                    33%           37 : 63
# 3       15596.0                  7.8                    22%           42 : 58
# 4        7929.0                  8.4                    27%           45 : 55
#
#    year
# 0  2011
# 1  2011
# 2  2011
# 3  2011
# 4  2011

# %%
shanghai = pd.read_csv(f'{data_folder}shanghaiData.csv')
shanghai.head()
# Out:
#   world_rank                              university_name national_rank  \
# 0          1                           Harvard University             1
# 1          2                      University of Cambridge             1
# 2          3                          Stanford University             2
# 3          4           University of California, Berkeley             3
# 4          5  Massachusetts Institute of Technology (MIT)             4
#
#    total_score  alumni  award   hici     ns    pub   pcp  year
# 0        100.0   100.0  100.0  100.0  100.0  100.0  72.4  2005
# 1         73.6    99.8   93.4   53.3   56.6   70.9  66.9  2005
# 2         73.4    41.1   72.2   88.5   70.9   72.3  65.0  2005
# 3         72.8    71.8   76.0   69.4   73.9   72.2  52.7  2005
# 4         70.1    74.0   80.6   66.7   65.8   64.3  53.0  2005

# %%
cwur = pd.read_csv(f'{data_folder}cwurData.csv')
cwur.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# 0             1          1          1           NaN        5  100.00  2012
# 1            12          4          4           NaN        1   91.67  2012
# 2             4          2          2           NaN       15   89.50  2012
# 3            16         16         11           NaN       50   86.17  2012
# 4            37         22         22           NaN       18   85.21  2012

# %% [markdown]
# Check of Na values

# %%
times.isnull().any()
# Out:
# world_rank                False
# university_name           False
# country                   False
# teaching                  False
# international             False
# research                  False
# citations                 False
# income                    False
# total_score               False
# num_students               True
# student_staff_ratio        True
# international_students     True
# female_male_ratio          True
# year                      False
# dtype: bool

# %%
shanghai.isnull().any()
# Out:
# world_rank         False
# university_name     True
# national_rank       True
# total_score         True
# alumni              True
# award               True
# hici                True
# ns                  True
# pub                 True
# pcp                 True
# year               False
# dtype: bool

# %%
shanghai[shanghai['university_name'].isnull()]
# Out:
#      world_rank university_name national_rank  total_score  alumni  award  \
# 3896         99             NaN           NaN          NaN     NaN    NaN
#
#       hici  ns  pub  pcp  year
# 3896   NaN NaN  NaN  NaN  2013

# %% [markdown]
# This row will be deleted from the dataset because in this context the missing value associated to *university_name* makes the row itself meaningless

# %%
shanghai.dropna(subset = ['university_name'], inplace = True)

# %%
shanghai.isnull().any()
# Out:
# world_rank         False
# university_name    False
# national_rank      False
# total_score         True
# alumni             False
# award               True
# hici                True
# ns                  True
# pub                 True
# pcp                 True
# year               False
# dtype: bool

# %%
cwur.isnull().any()
# Out:
# world_rank              False
# institution             False
# country                 False
# national_rank           False
# quality_of_education    False
# alumni_employment       False
# quality_of_faculty      False
# publications            False
# influence               False
# citations               False
# broad_impact             True
# patents                 False
# score                   False
# year                    False
# dtype: bool

# %% [markdown]
# ## 1. For each university, extract from the times dataset the most recent and the least recent data, obtaining two separate dataframes

# %%
times['year'].dtype
# Out:
# dtype('int64')

# %%
times[times['university_name'] == 'Harvard University']
# Out:
#      world_rank     university_name                   country  teaching  \
# 0             1  Harvard University  United States of America      99.7
# 201           2  Harvard University  United States of America      95.8
# 605           4  Harvard University  United States of America      94.9
# 1003          2  Harvard University  United States of America      95.3
# 1403          2  Harvard University  United States of America      92.9
# 1808          6  Harvard University  United States of America      83.6
#
#      international  research  citations income total_score  num_students  \
# 0             72.4      98.7       98.8   34.5        96.1       20152.0
# 201           67.5      97.4       99.8   35.9        93.9       20152.0
# 605           63.7      98.6       99.2   39.9        93.6       20152.0
# 1003          66.2      98.5       99.1   40.6        93.9       20152.0
# 1403          67.6      98.6       98.9   44.0        93.3       20152.0
# 1808          77.2      99.0       99.8   45.2        91.6       20152.0
#
#       student_staff_ratio international_students female_male_ratio  year
# 0                     8.9                    25%               NaN  2011
# 201                   8.9                    25%               NaN  2012
# 605                   8.9                    25%               NaN  2013
# 1003                  8.9                    25%               NaN  2014
# 1403                  8.9                    25%               NaN  2015
# 1808                  8.9                    25%               NaN  2016

# %%
times_max_year = times.iloc[times.groupby('university_name').idxmax()['year']].copy()
times_max_year.head()
# Out:
#      world_rank                           university_name         country  \
# 2405    601-800  AGH University of Science and Technology          Poland
# 2003    201-250                        Aalborg University         Denmark
# 2056    251-300                          Aalto University         Finland
# 1908       =106                         Aarhus University         Denmark
# 2105    301-350                    Aberystwyth University  United Kingdom
#
#       teaching international  research  citations income total_score  \
# 2405      14.2          17.9       3.7       35.7      -           -
# 2003      25.1          71.0      28.4       73.8   43.7           -
# 2056      31.1          65.4      32.8       62.1   61.6           -
# 1908      36.9          76.8      50.7       79.8   68.3        57.7
# 2105      21.6          72.2      18.9       67.2   31.3           -
#
#       num_students  student_staff_ratio international_students  \
# 2405       35569.0                 17.0                     1%
# 2003       17422.0                 15.9                    15%
# 2056       16099.0                 24.2                    17%
# 1908       23895.0                 13.6                    14%
# 2105        9252.0                 19.2                    18%
#
#      female_male_ratio  year
# 2405                 -  2016
# 2003           48 : 52  2016
# 2056           32 : 68  2016
# 1908           54 : 46  2016
# 2105           48 : 52  2016

# %%
times_min_year = times.iloc[times.groupby('university_name').idxmin()['year']]
times_min_year.head()
# Out:
#      world_rank                           university_name         country  \
# 2405    601-800  AGH University of Science and Technology          Poland
# 501     301-350                        Aalborg University         Denmark
# 502     301-350                          Aalto University         Finland
# 166         167                         Aarhus University         Denmark
# 476     276-300                    Aberystwyth University  United Kingdom
#
#       teaching international  research  citations income total_score  \
# 2405      14.2          17.9       3.7       35.7      -           -
# 501       19.0          75.3      20.0       27.1   36.4           -
# 502       26.2          49.0      22.2       37.5   61.9           -
# 166       38.1          33.4      55.6       57.3   61.5        49.9
# 476       19.8          63.8      15.5       56.6   35.5           -
#
#       num_students  student_staff_ratio international_students  \
# 2405       35569.0                 17.0                     1%
# 501        17422.0                 15.9                    15%
# 502        16099.0                 24.2                    17%
# 166        23895.0                 13.6                    14%
# 476         9252.0                 19.2                    18%
#
#      female_male_ratio  year
# 2405                 -  2016
# 501            48 : 52  2012
# 502            32 : 68  2012
# 166            54 : 46  2011
# 476            48 : 52  2012

# %% [markdown]
# ## 2. For each university, compute the improvement in income between the least recent and the most recent data points

# %%
merged = pd.merge(times_min_year, times_max_year, on = ['university_name', 'country'], suffixes = ['_min', '_max'])
merged.head()
# Out:
#   world_rank_min                           university_name         country  \
# 0        601-800  AGH University of Science and Technology          Poland
# 1        301-350                        Aalborg University         Denmark
# 2        301-350                          Aalto University         Finland
# 3            167                         Aarhus University         Denmark
# 4        276-300                    Aberystwyth University  United Kingdom
#
#    teaching_min international_min  research_min  citations_min income_min  \
# 0          14.2              17.9           3.7           35.7          -
# 1          19.0              75.3          20.0           27.1       36.4
# 2          26.2              49.0          22.2           37.5       61.9
# 3          38.1              33.4          55.6           57.3       61.5
# 4          19.8              63.8          15.5           56.6       35.5
#
#   total_score_min  num_students_min  ...  international_max research_max  \
# 0               -           35569.0  ...               17.9          3.7
# 1               -           17422.0  ...               71.0         28.4
# 2               -           16099.0  ...               65.4         32.8
# 3            49.9           23895.0  ...               76.8         50.7
# 4               -            9252.0  ...               72.2         18.9
#
#   citations_max  income_max total_score_max  num_students_max  \
# 0          35.7           -               -           35569.0
# 1          73.8        43.7               -           17422.0
# 2          62.1        61.6               -           16099.0
# 3          79.8        68.3            57.7           23895.0
# 4          67.2        31.3               -            9252.0
#
#   student_staff_ratio_max  international_students_max  female_male_ratio_max  \
# 0                    17.0                          1%                      -
# 1                    15.9                         15%                48 : 52
# 2                    24.2                         17%                32 : 68
# 3                    13.6                         14%                54 : 46
# 4                    19.2                         18%                48 : 52
#
#   year_max
# 0     2016
# 1     2016
# 2     2016
# 3     2016
# 4     2016
#
# [5 rows x 26 columns]

# %%
merged[merged['university_name'] == 'Harvard University']['income_max'].dtype
# Out:
# dtype('O')

# %%
def difference(row):
    if (row['income_max'] == '-') or (row['income_min'] == '-'):
        return 'data not available'
    else:
        return float(row['income_max']) - float(row['income_min'])

# %%
merged['difference_for'] = merged.apply(difference, axis = 1)
merged.head()
# Out:
#   world_rank_min                           university_name         country  \
# 0        601-800  AGH University of Science and Technology          Poland
# 1        301-350                        Aalborg University         Denmark
# 2        301-350                          Aalto University         Finland
# 3            167                         Aarhus University         Denmark
# 4        276-300                    Aberystwyth University  United Kingdom
#
#    teaching_min international_min  research_min  citations_min income_min  \
# 0          14.2              17.9           3.7           35.7          -
# 1          19.0              75.3          20.0           27.1       36.4
# 2          26.2              49.0          22.2           37.5       61.9
# 3          38.1              33.4          55.6           57.3       61.5
# 4          19.8              63.8          15.5           56.6       35.5
#
#   total_score_min  num_students_min  ...  research_max citations_max  \
# 0               -           35569.0  ...           3.7          35.7
# 1               -           17422.0  ...          28.4          73.8
# 2               -           16099.0  ...          32.8          62.1
# 3            49.9           23895.0  ...          50.7          79.8
# 4               -            9252.0  ...          18.9          67.2
#
#   income_max  total_score_max num_students_max  student_staff_ratio_max  \
# 0          -                -          35569.0                     17.0
# 1       43.7                -          17422.0                     15.9
# 2       61.6                -          16099.0                     24.2
# 3       68.3             57.7          23895.0                     13.6
# 4       31.3                -           9252.0                     19.2
#
#   international_students_max  female_male_ratio_max  year_max  \
# 0                         1%                      -      2016
# 1                        15%                48 : 52      2016
# 2                        17%                32 : 68      2016
# 3                        14%                54 : 46      2016
# 4                        18%                48 : 52      2016
#
#        difference_for
# 0  data not available
# 1                 7.3
# 2                -0.3
# 3                 6.8
# 4                -4.2
#
# [5 rows x 27 columns]

# %%
merged['income_max'] = pd.to_numeric(merged['income_max'], errors = 'coerce')
merged['income_min'] = pd.to_numeric(merged['income_min'], errors = 'coerce')
merged.head()
# Out:
#   world_rank_min                           university_name         country  \
# 0        601-800  AGH University of Science and Technology          Poland
# 1        301-350                        Aalborg University         Denmark
# 2        301-350                          Aalto University         Finland
# 3            167                         Aarhus University         Denmark
# 4        276-300                    Aberystwyth University  United Kingdom
#
#    teaching_min international_min  research_min  citations_min  income_min  \
# 0          14.2              17.9           3.7           35.7         NaN
# 1          19.0              75.3          20.0           27.1        36.4
# 2          26.2              49.0          22.2           37.5        61.9
# 3          38.1              33.4          55.6           57.3        61.5
# 4          19.8              63.8          15.5           56.6        35.5
#
#   total_score_min  num_students_min  ...  research_max citations_max  \
# 0               -           35569.0  ...           3.7          35.7
# 1               -           17422.0  ...          28.4          73.8
# 2               -           16099.0  ...          32.8          62.1
# 3            49.9           23895.0  ...          50.7          79.8
# 4               -            9252.0  ...          18.9          67.2
#
#   income_max  total_score_max num_students_max  student_staff_ratio_max  \
# 0        NaN                -          35569.0                     17.0
# 1       43.7                -          17422.0                     15.9
# 2       61.6                -          16099.0                     24.2
# 3       68.3             57.7          23895.0                     13.6
# 4       31.3                -           9252.0                     19.2
#
#   international_students_max  female_male_ratio_max  year_max  \
# 0                         1%                      -      2016
# 1                        15%                48 : 52      2016
# 2                        17%                32 : 68      2016
# 3                        14%                54 : 46      2016
# 4                        18%                48 : 52      2016
#
#        difference_for
# 0  data not available
# 1                 7.3
# 2                -0.3
# 3                 6.8
# 4                -4.2
#
# [5 rows x 27 columns]

# %%
merged['difference'] = merged['income_max'] - merged['income_min']
merged.head()
# Out:
#   world_rank_min                           university_name         country  \
# 0        601-800  AGH University of Science and Technology          Poland
# 1        301-350                        Aalborg University         Denmark
# 2        301-350                          Aalto University         Finland
# 3            167                         Aarhus University         Denmark
# 4        276-300                    Aberystwyth University  United Kingdom
#
#    teaching_min international_min  research_min  citations_min  income_min  \
# 0          14.2              17.9           3.7           35.7         NaN
# 1          19.0              75.3          20.0           27.1        36.4
# 2          26.2              49.0          22.2           37.5        61.9
# 3          38.1              33.4          55.6           57.3        61.5
# 4          19.8              63.8          15.5           56.6        35.5
#
#   total_score_min  num_students_min  ...  citations_max income_max  \
# 0               -           35569.0  ...           35.7        NaN
# 1               -           17422.0  ...           73.8       43.7
# 2               -           16099.0  ...           62.1       61.6
# 3            49.9           23895.0  ...           79.8       68.3
# 4               -            9252.0  ...           67.2       31.3
#
#   total_score_max  num_students_max student_staff_ratio_max  \
# 0               -           35569.0                    17.0
# 1               -           17422.0                    15.9
# 2               -           16099.0                    24.2
# 3            57.7           23895.0                    13.6
# 4               -            9252.0                    19.2
#
#    international_students_max female_male_ratio_max  year_max  \
# 0                          1%                     -      2016
# 1                         15%               48 : 52      2016
# 2                         17%               32 : 68      2016
# 3                         14%               54 : 46      2016
# 4                         18%               48 : 52      2016
#
#        difference_for  difference
# 0  data not available         NaN
# 1                 7.3         7.3
# 2                -0.3        -0.3
# 3                 6.8         6.8
# 4                -4.2        -4.2
#
# [5 rows x 28 columns]

# %%
merged[['difference_for', 'difference']]
# Out:
#          difference_for  difference
# 0    data not available         NaN
# 1                   7.3         7.3
# 2                  -0.3        -0.3
# 3                   6.8         6.8
# 4                  -4.2        -4.2
# ..                  ...         ...
# 811                 6.4         6.4
# 812                 5.6         5.6
# 813  data not available         NaN
# 814                27.4        27.4
# 815                   0         0.0
#
# [816 rows x 2 columns]

# %% [markdown]
# ## 3. Find the university with the largest increase computed in the previous point

# %%
merged[merged['difference_for'] != 'data not available'].sort_values('difference_for', ascending = False)
# Out:
#     world_rank_min                      university_name  \
# 427        251-275                           TU Dresden
# 277            174     Nanyang Technological University
# 229             61                           LMU Munich
# 204            187    Karlsruhe Institute of Technology
# 275        201-225                    Nagoya University
# ..             ...                                  ...
# 434            122      Technical University of Denmark
# 585        276-300                University of Iceland
# 236            124                    Leiden University
# 490             95                University of Arizona
# 413        226-250  State University of New York Albany
#
#                       country  teaching_min international_min  research_min  \
# 427                   Germany          27.3              49.2          13.8
# 277                 Singapore          43.6              96.3          51.7
# 229                   Germany          59.1              43.1          57.5
# 204                   Germany          45.0              47.3          35.4
# 275                     Japan          45.5              21.2          39.2
# ..                        ...           ...               ...           ...
# 434                   Denmark          46.2              64.0          46.9
# 585                   Iceland          10.7              56.9          17.3
# 236               Netherlands          47.3              40.0          54.9
# 490  United States of America          52.4              21.9          52.2
# 413  United States of America          25.7              25.9          30.8
#
#      citations_min  income_min total_score_min  num_students_min  ...  \
# 427           57.4        31.9               -           35487.0  ...
# 277           45.0        40.0            49.0           25028.0  ...
# 229           76.4        40.4            63.0           35691.0  ...
# 204           60.7        40.0            47.2           25294.0  ...
# 275           43.8        33.1               -           15529.0  ...
# ..             ...         ...             ...               ...  ...
# 434           64.6        95.5            54.5            9990.0  ...
# 585           62.4        75.4               -           13960.0  ...
# 236           59.3       100.0            54.4           21222.0  ...
# 490           70.1        84.2            57.3           36429.0  ...
# 413           53.5        92.9               -           15387.0  ...
#
#      citations_max income_max total_score_max  num_students_max  \
# 427           66.1       99.7            52.1           35487.0
# 277           85.6       99.9            68.2           25028.0
# 229           85.7      100.0            77.3           35691.0
# 204           73.8       99.5            54.5           25294.0
# 275           40.1       91.4               -           15529.0
# ..             ...        ...             ...               ...
# 434           77.8       50.0            51.1            9990.0
# 585           91.4       28.0               -           13960.0
# 236           85.2       49.8            65.7           21222.0
# 490           79.5       32.4            51.7           36429.0
# 413           35.5       28.0               -           15387.0
#
#     student_staff_ratio_max  international_students_max female_male_ratio_max  \
# 427                    37.4                         12%               42 : 58
# 277                    16.2                         33%               48 : 52
# 229                    15.5                         13%               62 : 38
# 204                    24.6                         16%               26 : 74
# 275                     7.9                         10%               29 : 71
# ..                      ...                         ...                   ...
# 434                     5.0                         18%               27 : 73
# 585                    25.9                          8%               66 : 34
# 236                    17.1                         10%               59 : 41
# 490                    12.7                          8%               52 : 48
# 413                    18.5                          8%               51 : 49
#
#      year_max  difference_for  difference
# 427      2016            67.8        67.8
# 277      2016            59.9        59.9
# 229      2016            59.6        59.6
# 204      2016            59.5        59.5
# 275      2016            58.3        58.3
# ..        ...             ...         ...
# 434      2016           -45.5       -45.5
# 585      2016           -47.4       -47.4
# 236      2016           -50.2       -50.2
# 490      2016           -51.8       -51.8
# 413      2016           -64.9       -64.9
#
# [703 rows x 28 columns]

# %%
#soluzione con ciclo for

temp = -1000

for i in range(1, len(merged)-1):
    
    if merged.iloc[i]['difference'] != 'data not available':
        if merged.iloc[i]['difference'] > temp:
                temp = merged.iloc[i]['difference']
                index = i
        
merged.iloc[index]
# Out:
# world_rank_min                   251-275
# university_name               TU Dresden
# country                          Germany
# teaching_min                        27.3
# international_min                   49.2
# research_min                        13.8
# citations_min                       57.4
# income_min                          31.9
# total_score_min                        -
# num_students_min                   35487
# student_staff_ratio_min             37.4
# international_students_min           12%
# female_male_ratio_min            42 : 58
# year_min                            2012
# world_rank_max                      =158
# teaching_max                        41.4
# international_max                   47.7
# research_max                        45.8
# citations_max                       66.1
# income_max                          99.7
# total_score_max                     52.1
# num_students_max                   35487
# student_staff_ratio_max             37.4
# international_students_max           12%
# female_male_ratio_max            42 : 58
# year_max                            2016
# difference_for                      67.8
# difference                          67.8
# Name: 427, dtype: object

# %%
merged.iloc[merged['difference'].idxmax()]['university_name']
# Out:
# 'TU Dresden'

# %%
merged[['income_max', 'income_min', 'difference', 'difference_for']]
# Out:
#      income_max  income_min  difference      difference_for
# 0           NaN         NaN         NaN  data not available
# 1          43.7        36.4         7.3                 7.3
# 2          61.6        61.9        -0.3                -0.3
# 3          68.3        61.5         6.8                 6.8
# 4          31.3        35.5        -4.2                -4.2
# ..          ...         ...         ...                 ...
# 811        37.1        30.7         6.4                 6.4
# 812        31.7        26.1         5.6                 5.6
# 813        82.3         NaN         NaN  data not available
# 814        65.4        38.0        27.4                27.4
# 815        29.8        29.8         0.0                   0
#
# [816 rows x 4 columns]

# %% [markdown]
# ## 4. For each ranking, consider only the most recent data point. For each university, compute the maximum difference between the rankings (e.g. for Aarhus University the value is 122-73=49). Notice that some rankings are expressed as a range

# %%
shanghai_max_year = shanghai.iloc[shanghai.groupby('university_name').idxmax()['year']][['world_rank', 'university_name']]
shanghai_max_year.set_index('university_name', inplace = True)
shanghai_max_year.head()
# Out:
#                          world_rank
# university_name
# Aalborg University          301-400
# Aalto University            401-500
# Aarhus University                73
# Aix Marseille University    101-150
# Aix-Marseille University    102-150

# %%
cwur_max_year = cwur.iloc[cwur.groupby('institution').idxmax()['year']][['world_rank', 'institution']]
cwur_max_year.set_index('institution', inplace = True)
cwur_max_year.head()
# Out:
#                                           world_rank
# institution
# AGH University of Science and Technology         782
# Aalborg University                               565
# Aalto University                                 421
# Aarhus University                                122
# Aberystwyth University                           814

# %%
times_max_year.set_index('university_name', inplace = True)

# %%
from functools import reduce

# %%
datasets = [times_max_year['world_rank'], shanghai_max_year, cwur_max_year]

# %%
rankings = reduce(lambda left, right: pd.merge(left, right, left_index = True, right_index = True, how = 'outer'), datasets)
rankings.head()
# Out:
#                                          world_rank_x world_rank_y  world_rank
# AGH University of Science and Technology      601-800          NaN       782.0
# Aalborg University                            201-250      301-400       565.0
# Aalto University                              251-300      401-500       421.0
# Aarhus University                                =106           73       122.0
# Aberystwyth University                        301-350          NaN       814.0

# %%
def newrank(string):
    #if string.isnull(): 
    if type(string) != str:
        return string
    else:
        occ1 = re.search('(?P<min>\d+)-(?P<max>\d+)', string)
        occ2 = re.search('^\D?(?P<num>\d+)$', string)
        if occ1:
            #per i range consideriamo la media?
            return (float(occ1.group('min')) + float(occ1.group('max')))/2
        elif occ2:
            return float(occ2.group('num'))

# %%
rankings['world_rank_x_num'] = rankings['world_rank_x'].apply(newrank)
rankings['world_rank_y_num'] = rankings['world_rank_y'].apply(newrank)
rankings 
#pop?
# Out:
#                                          world_rank_x world_rank_y  \
# AGH University of Science and Technology      601-800          NaN
# Aalborg University                            201-250      301-400
# Aalto University                              251-300      401-500
# Aarhus University                                =106           73
# Aberystwyth University                        301-350          NaN
# ...                                               ...          ...
# École centrale de Lyon                            NaN          NaN
# École normale supérieure - Paris                  NaN          NaN
# École normale supérieure de Cachan                NaN          NaN
# École normale supérieure de Lyon                  NaN          NaN
# Örebro University                             301-350          NaN
#
#                                           world_rank  world_rank_x_num  \
# AGH University of Science and Technology       782.0             700.5
# Aalborg University                             565.0             225.5
# Aalto University                               421.0             275.5
# Aarhus University                              122.0             106.0
# Aberystwyth University                         814.0             325.5
# ...                                              ...               ...
# École centrale de Lyon                         881.0               NaN
# École normale supérieure - Paris                37.0               NaN
# École normale supérieure de Cachan             721.0               NaN
# École normale supérieure de Lyon               471.0               NaN
# Örebro University                              639.0             325.5
#
#                                           world_rank_y_num
# AGH University of Science and Technology               NaN
# Aalborg University                                   350.5
# Aalto University                                     450.5
# Aarhus University                                     73.0
# Aberystwyth University                                 NaN
# ...                                                    ...
# École centrale de Lyon                                 NaN
# École normale supérieure - Paris                       NaN
# École normale supérieure de Cachan                     NaN
# École normale supérieure de Lyon                       NaN
# Örebro University                                      NaN
#
# [1452 rows x 5 columns]

# %%
rankings['world_rank'].dtype
# Out:
# dtype('float64')

# %%
def absolute_difference(row):
    item1 = row['world_rank_x_num']
    item2 = row['world_rank_y_num']
    item3 = row['world_rank']
    return max(abs(item1 - item2), abs(item1 - item3), abs(item3 - item2))

# %%
rankings['absolute_difference'] = rankings.apply(absolute_difference, axis = 1)
rankings
# Out:
#                                          world_rank_x world_rank_y  \
# AGH University of Science and Technology      601-800          NaN
# Aalborg University                            201-250      301-400
# Aalto University                              251-300      401-500
# Aarhus University                                =106           73
# Aberystwyth University                        301-350          NaN
# ...                                               ...          ...
# École centrale de Lyon                            NaN          NaN
# École normale supérieure - Paris                  NaN          NaN
# École normale supérieure de Cachan                NaN          NaN
# École normale supérieure de Lyon                  NaN          NaN
# Örebro University                             301-350          NaN
#
#                                           world_rank  world_rank_x_num  \
# AGH University of Science and Technology       782.0             700.5
# Aalborg University                             565.0             225.5
# Aalto University                               421.0             275.5
# Aarhus University                              122.0             106.0
# Aberystwyth University                         814.0             325.5
# ...                                              ...               ...
# École centrale de Lyon                         881.0               NaN
# École normale supérieure - Paris                37.0               NaN
# École normale supérieure de Cachan             721.0               NaN
# École normale supérieure de Lyon               471.0               NaN
# Örebro University                              639.0             325.5
#
#                                           world_rank_y_num  \
# AGH University of Science and Technology               NaN
# Aalborg University                                   350.5
# Aalto University                                     450.5
# Aarhus University                                     73.0
# Aberystwyth University                                 NaN
# ...                                                    ...
# École centrale de Lyon                                 NaN
# École normale supérieure - Paris                       NaN
# École normale supérieure de Cachan                     NaN
# École normale supérieure de Lyon                       NaN
# Örebro University                                      NaN
#
#                                           absolute_difference
# AGH University of Science and Technology                  NaN
# Aalborg University                                      339.5
# Aalto University                                        175.0
# Aarhus University                                        49.0
# Aberystwyth University                                    NaN
# ...                                                       ...
# École centrale de Lyon                                    NaN
# École normale supérieure - Paris                          NaN
# École normale supérieure de Cachan                        NaN
# École normale supérieure de Lyon                          NaN
# Örebro University                                         NaN
#
# [1452 rows x 6 columns]

# %% [markdown]
# ## 5. Consider only the most recent data point of the times dataset. Compute the number of male and female students for each country.

# %%
times_max_year.head()
# Out:
#                                          world_rank         country  teaching  \
# university_name
# AGH University of Science and Technology    601-800          Poland      14.2
# Aalborg University                          201-250         Denmark      25.1
# Aalto University                            251-300         Finland      31.1
# Aarhus University                              =106         Denmark      36.9
# Aberystwyth University                      301-350  United Kingdom      21.6
#
#                                          international  research  citations  \
# university_name
# AGH University of Science and Technology          17.9       3.7       35.7
# Aalborg University                                71.0      28.4       73.8
# Aalto University                                  65.4      32.8       62.1
# Aarhus University                                 76.8      50.7       79.8
# Aberystwyth University                            72.2      18.9       67.2
#
#                                          income total_score  num_students  \
# university_name
# AGH University of Science and Technology      -           -       35569.0
# Aalborg University                         43.7           -       17422.0
# Aalto University                           61.6           -       16099.0
# Aarhus University                          68.3        57.7       23895.0
# Aberystwyth University                     31.3           -        9252.0
#
#                                           student_staff_ratio  \
# university_name
# AGH University of Science and Technology                 17.0
# Aalborg University                                       15.9
# Aalto University                                         24.2
# Aarhus University                                        13.6
# Aberystwyth University                                   19.2
#
#                                          international_students  \
# university_name
# AGH University of Science and Technology                     1%
# Aalborg University                                          15%
# Aalto University                                            17%
# Aarhus University                                           14%
# Aberystwyth University                                      18%
#
#                                          female_male_ratio  year
# university_name
# AGH University of Science and Technology                 -  2016
# Aalborg University                                 48 : 52  2016
# Aalto University                                   32 : 68  2016
# Aarhus University                                  54 : 46  2016
# Aberystwyth University                             48 : 52  2016

# %%
print(f"the total number of rows is: {len(times_max_year)}")
print(f"the number of rows with missing 'female_male_ratio' values is: {len(times_max_year[(times_max_year['female_male_ratio'] == '-') | (times_max_year['female_male_ratio'].isnull())])}")
# Out:
# the total number of rows is: 818
# the number of rows with missing 'female_male_ratio' values is: 79

# %%
#rows with missing 'female_male_ratio' values will be removed 
#this decision is taken because these rows won't contribute to the
#final result
#moreover, the number of such rows is significantly smaller (79 / 818) 
#than the total number of rows

# %%
times_max_year_clean = times_max_year[(times_max_year['female_male_ratio'] != '-') & (times_max_year['female_male_ratio'].notnull())].copy()
times_max_year_clean.head()
# Out:
#                            world_rank         country  teaching international  \
# university_name
# Aalborg University            201-250         Denmark      25.1          71.0
# Aalto University              251-300         Finland      31.1          65.4
# Aarhus University                =106         Denmark      36.9          76.8
# Aberystwyth University        301-350  United Kingdom      21.6          72.2
# Adam Mickiewicz University    601-800          Poland      20.0          25.7
#
#                             research  citations income total_score  \
# university_name
# Aalborg University              28.4       73.8   43.7           -
# Aalto University                32.8       62.1   61.6           -
# Aarhus University               50.7       79.8   68.3        57.7
# Aberystwyth University          18.9       67.2   31.3           -
# Adam Mickiewicz University      11.0       15.3   28.7           -
#
#                             num_students  student_staff_ratio  \
# university_name
# Aalborg University               17422.0                 15.9
# Aalto University                 16099.0                 24.2
# Aarhus University                23895.0                 13.6
# Aberystwyth University            9252.0                 19.2
# Adam Mickiewicz University       40633.0                 15.6
#
#                            international_students female_male_ratio  year
# university_name
# Aalborg University                            15%           48 : 52  2016
# Aalto University                              17%           32 : 68  2016
# Aarhus University                             14%           54 : 46  2016
# Aberystwyth University                        18%           48 : 52  2016
# Adam Mickiewicz University                     1%           71 : 29  2016

# %%
def female_male(row):
    occurrence = re.search('(?P<female>\d+) : (?P<male>\d+)', row['female_male_ratio'])
    if occurrence:
        female = float(occurrence.group('female'))*0.01*row['num_students']
        male = float(occurrence.group('male'))*0.01*row['num_students']
        return [int(round(female)), int(round(male))]
    else:
        return 'Error' 
        #in this way we can control if there are different formats of 'female_male_ratio'
        #that need to be handled

# %%
times_max_year_clean['female_male_student'] = times_max_year_clean.apply(female_male, axis = 1)
times_max_year_clean
# Out:
#                                          world_rank         country  teaching  \
# university_name
# Aalborg University                          201-250         Denmark      25.1
# Aalto University                            251-300         Finland      31.1
# Aarhus University                              =106         Denmark      36.9
# Aberystwyth University                      301-350  United Kingdom      21.6
# Adam Mickiewicz University                  601-800          Poland      20.0
# ...                                             ...             ...       ...
# École Normale Supérieure                         54          France      70.6
# École Normale Supérieure de Lyon            201-250          France      41.6
# École Polytechnique                            =101          France      53.5
# École Polytechnique Fédérale de Lausanne         31     Switzerland      61.3
# Örebro University                           301-350          Sweden      18.3
#
#                                          international  research  citations  \
# university_name
# Aalborg University                                71.0      28.4       73.8
# Aalto University                                  65.4      32.8       62.1
# Aarhus University                                 76.8      50.7       79.8
# Aberystwyth University                            72.2      18.9       67.2
# Adam Mickiewicz University                        25.7      11.0       15.3
# ...                                                ...       ...        ...
# École Normale Supérieure                          85.5      47.7       87.1
# École Normale Supérieure de Lyon                  65.6      30.0       69.0
# École Polytechnique                               92.8      44.6       64.7
# École Polytechnique Fédérale de Lausanne          98.6      67.5       94.6
# Örebro University                                 39.4      10.4       87.8
#
#                                          income total_score  num_students  \
# university_name
# Aalborg University                         43.7           -       17422.0
# Aalto University                           61.6           -       16099.0
# Aarhus University                          68.3        57.7       23895.0
# Aberystwyth University                     31.3           -        9252.0
# Adam Mickiewicz University                 28.7           -       40633.0
# ...                                         ...         ...           ...
# École Normale Supérieure                   37.1        69.0        2400.0
# École Normale Supérieure de Lyon           31.7           -        2218.0
# École Polytechnique                        82.3        57.9        2429.0
# École Polytechnique Fédérale de Lausanne   65.4        76.1        9666.0
# Örebro University                          29.8           -        8788.0
#
#                                           student_staff_ratio  \
# university_name
# Aalborg University                                       15.9
# Aalto University                                         24.2
# Aarhus University                                        13.6
# Aberystwyth University                                   19.2
# Adam Mickiewicz University                               15.6
# ...                                                       ...
# École Normale Supérieure                                  7.9
# École Normale Supérieure de Lyon                          8.0
# École Polytechnique                                       4.8
# École Polytechnique Fédérale de Lausanne                 10.5
# Örebro University                                        15.8
#
#                                          international_students  \
# university_name
# Aalborg University                                          15%
# Aalto University                                            17%
# Aarhus University                                           14%
# Aberystwyth University                                      18%
# Adam Mickiewicz University                                   1%
# ...                                                         ...
# École Normale Supérieure                                    20%
# École Normale Supérieure de Lyon                            14%
# École Polytechnique                                         30%
# École Polytechnique Fédérale de Lausanne                    54%
# Örebro University                                            2%
#
#                                          female_male_ratio  year  \
# university_name
# Aalborg University                                 48 : 52  2016
# Aalto University                                   32 : 68  2016
# Aarhus University                                  54 : 46  2016
# Aberystwyth University                             48 : 52  2016
# Adam Mickiewicz University                         71 : 29  2016
# ...                                                    ...   ...
# École Normale Supérieure                           46 : 54  2016
# École Normale Supérieure de Lyon                   49 : 51  2016
# École Polytechnique                                18 : 82  2016
# École Polytechnique Fédérale de Lausanne           27 : 73  2016
# Örebro University                                  61 : 39  2016
#
#                                          female_male_student
# university_name
# Aalborg University                              [8363, 9059]
# Aalto University                               [5152, 10947]
# Aarhus University                             [12903, 10992]
# Aberystwyth University                          [4441, 4811]
# Adam Mickiewicz University                    [28849, 11784]
# ...                                                      ...
# École Normale Supérieure                        [1104, 1296]
# École Normale Supérieure de Lyon                [1087, 1131]
# École Polytechnique                              [437, 1992]
# École Polytechnique Fédérale de Lausanne        [2610, 7056]
# Örebro University                               [5361, 3427]
#
# [739 rows x 14 columns]

# %%
print(f"the number of rows with 'female_male_student' == 'Error' is {len(times_max_year_clean[times_max_year_clean['female_male_student'] == 'Error'])}")
# Out:
# the number of rows with 'female_male_student' == 'Error' is 0

# %% [markdown]
# It has been verified that the only format of _female_male_ratio_ is
# <code>\d+ : \d+</code>

# %%
times_max_year_clean['female'], times_max_year_clean['male'] =  zip(*times_max_year_clean['female_male_student'])

# %%
times_max_year_clean
# Out:
#                                          world_rank         country  teaching  \
# university_name
# Aalborg University                          201-250         Denmark      25.1
# Aalto University                            251-300         Finland      31.1
# Aarhus University                              =106         Denmark      36.9
# Aberystwyth University                      301-350  United Kingdom      21.6
# Adam Mickiewicz University                  601-800          Poland      20.0
# ...                                             ...             ...       ...
# École Normale Supérieure                         54          France      70.6
# École Normale Supérieure de Lyon            201-250          France      41.6
# École Polytechnique                            =101          France      53.5
# École Polytechnique Fédérale de Lausanne         31     Switzerland      61.3
# Örebro University                           301-350          Sweden      18.3
#
#                                          international  research  citations  \
# university_name
# Aalborg University                                71.0      28.4       73.8
# Aalto University                                  65.4      32.8       62.1
# Aarhus University                                 76.8      50.7       79.8
# Aberystwyth University                            72.2      18.9       67.2
# Adam Mickiewicz University                        25.7      11.0       15.3
# ...                                                ...       ...        ...
# École Normale Supérieure                          85.5      47.7       87.1
# École Normale Supérieure de Lyon                  65.6      30.0       69.0
# École Polytechnique                               92.8      44.6       64.7
# École Polytechnique Fédérale de Lausanne          98.6      67.5       94.6
# Örebro University                                 39.4      10.4       87.8
#
#                                          income total_score  num_students  \
# university_name
# Aalborg University                         43.7           -       17422.0
# Aalto University                           61.6           -       16099.0
# Aarhus University                          68.3        57.7       23895.0
# Aberystwyth University                     31.3           -        9252.0
# Adam Mickiewicz University                 28.7           -       40633.0
# ...                                         ...         ...           ...
# École Normale Supérieure                   37.1        69.0        2400.0
# École Normale Supérieure de Lyon           31.7           -        2218.0
# École Polytechnique                        82.3        57.9        2429.0
# École Polytechnique Fédérale de Lausanne   65.4        76.1        9666.0
# Örebro University                          29.8           -        8788.0
#
#                                           student_staff_ratio  \
# university_name
# Aalborg University                                       15.9
# Aalto University                                         24.2
# Aarhus University                                        13.6
# Aberystwyth University                                   19.2
# Adam Mickiewicz University                               15.6
# ...                                                       ...
# École Normale Supérieure                                  7.9
# École Normale Supérieure de Lyon                          8.0
# École Polytechnique                                       4.8
# École Polytechnique Fédérale de Lausanne                 10.5
# Örebro University                                        15.8
#
#                                          international_students  \
# university_name
# Aalborg University                                          15%
# Aalto University                                            17%
# Aarhus University                                           14%
# Aberystwyth University                                      18%
# Adam Mickiewicz University                                   1%
# ...                                                         ...
# École Normale Supérieure                                    20%
# École Normale Supérieure de Lyon                            14%
# École Polytechnique                                         30%
# École Polytechnique Fédérale de Lausanne                    54%
# Örebro University                                            2%
#
#                                          female_male_ratio  year  \
# university_name
# Aalborg University                                 48 : 52  2016
# Aalto University                                   32 : 68  2016
# Aarhus University                                  54 : 46  2016
# Aberystwyth University                             48 : 52  2016
# Adam Mickiewicz University                         71 : 29  2016
# ...                                                    ...   ...
# École Normale Supérieure                           46 : 54  2016
# École Normale Supérieure de Lyon                   49 : 51  2016
# École Polytechnique                                18 : 82  2016
# École Polytechnique Fédérale de Lausanne           27 : 73  2016
# Örebro University                                  61 : 39  2016
#
#                                          female_male_student  female   male
# university_name
# Aalborg University                              [8363, 9059]    8363   9059
# Aalto University                               [5152, 10947]    5152  10947
# Aarhus University                             [12903, 10992]   12903  10992
# Aberystwyth University                          [4441, 4811]    4441   4811
# Adam Mickiewicz University                    [28849, 11784]   28849  11784
# ...                                                      ...     ...    ...
# École Normale Supérieure                        [1104, 1296]    1104   1296
# École Normale Supérieure de Lyon                [1087, 1131]    1087   1131
# École Polytechnique                              [437, 1992]     437   1992
# École Polytechnique Fédérale de Lausanne        [2610, 7056]    2610   7056
# Örebro University                               [5361, 3427]    5361   3427
#
# [739 rows x 16 columns]

# %%
students_per_country = times_max_year_clean.groupby('country')[['female', 'male', 'num_students']].sum()
students_per_country
# Out:
#                            female     male  num_students
# country
# Argentina                   67191    41182      108373.0
# Australia                  391736   321640      713376.0
# Austria                     68364    66113      134477.0
# Bangladesh                  21323    41393       62716.0
# Belarus                     20219     9084       29303.0
# ...                           ...      ...           ...
# Uganda                      18670    18670       37340.0
# Ukraine                     17846    19250       37096.0
# United Arab Emirates         9516     4931       14447.0
# United Kingdom             711815   613028     1324842.0
# United States of America  1601453  1556324     3157775.0
#
# [70 rows x 3 columns]

# %% [markdown]
# ## 6. Find the universities where the ratio between female and male is below the average ratio (computed over all universities)

# %%
def ratio(row):
    occurrence = re.search('(?P<female>\d+) : (?P<male>\d+)', row['female_male_ratio'])
    return np.float64(occurrence.group('female')) / np.float64(occurrence.group('male'))

# %%
times_max_year_clean['fm_ratio'] = times_max_year_clean.apply(ratio, axis = 1)
times_max_year_clean
# Out:
# <ipython-input-51-896dd627bba8>:3: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.float64(occurrence.group('female')) / np.float64(occurrence.group('male'))
#                                          world_rank         country  teaching  \
# university_name
# Aalborg University                          201-250         Denmark      25.1
# Aalto University                            251-300         Finland      31.1
# Aarhus University                              =106         Denmark      36.9
# Aberystwyth University                      301-350  United Kingdom      21.6
# Adam Mickiewicz University                  601-800          Poland      20.0
# ...                                             ...             ...       ...
# École Normale Supérieure                         54          France      70.6
# École Normale Supérieure de Lyon            201-250          France      41.6
# École Polytechnique                            =101          France      53.5
# École Polytechnique Fédérale de Lausanne         31     Switzerland      61.3
# Örebro University                           301-350          Sweden      18.3
#
#                                          international  research  citations  \
# university_name
# Aalborg University                                71.0      28.4       73.8
# Aalto University                                  65.4      32.8       62.1
# Aarhus University                                 76.8      50.7       79.8
# Aberystwyth University                            72.2      18.9       67.2
# Adam Mickiewicz University                        25.7      11.0       15.3
# ...                                                ...       ...        ...
# École Normale Supérieure                          85.5      47.7       87.1
# École Normale Supérieure de Lyon                  65.6      30.0       69.0
# École Polytechnique                               92.8      44.6       64.7
# École Polytechnique Fédérale de Lausanne          98.6      67.5       94.6
# Örebro University                                 39.4      10.4       87.8
#
#                                          income total_score  num_students  \
# university_name
# Aalborg University                         43.7           -       17422.0
# Aalto University                           61.6           -       16099.0
# Aarhus University                          68.3        57.7       23895.0
# Aberystwyth University                     31.3           -        9252.0
# Adam Mickiewicz University                 28.7           -       40633.0
# ...                                         ...         ...           ...
# École Normale Supérieure                   37.1        69.0        2400.0
# École Normale Supérieure de Lyon           31.7           -        2218.0
# École Polytechnique                        82.3        57.9        2429.0
# École Polytechnique Fédérale de Lausanne   65.4        76.1        9666.0
# Örebro University                          29.8           -        8788.0
#
#                                           student_staff_ratio  \
# university_name
# Aalborg University                                       15.9
# Aalto University                                         24.2
# Aarhus University                                        13.6
# Aberystwyth University                                   19.2
# Adam Mickiewicz University                               15.6
# ...                                                       ...
# École Normale Supérieure                                  7.9
# École Normale Supérieure de Lyon                          8.0
# École Polytechnique                                       4.8
# École Polytechnique Fédérale de Lausanne                 10.5
# Örebro University                                        15.8
#
#                                          international_students  \
# university_name
# Aalborg University                                          15%
# Aalto University                                            17%
# Aarhus University                                           14%
# Aberystwyth University                                      18%
# Adam Mickiewicz University                                   1%
# ...                                                         ...
# École Normale Supérieure                                    20%
# École Normale Supérieure de Lyon                            14%
# École Polytechnique                                         30%
# École Polytechnique Fédérale de Lausanne                    54%
# Örebro University                                            2%
#
#                                          female_male_ratio  year  \
# university_name
# Aalborg University                                 48 : 52  2016
# Aalto University                                   32 : 68  2016
# Aarhus University                                  54 : 46  2016
# Aberystwyth University                             48 : 52  2016
# Adam Mickiewicz University                         71 : 29  2016
# ...                                                    ...   ...
# École Normale Supérieure                           46 : 54  2016
# École Normale Supérieure de Lyon                   49 : 51  2016
# École Polytechnique                                18 : 82  2016
# École Polytechnique Fédérale de Lausanne           27 : 73  2016
# Örebro University                                  61 : 39  2016
#
#                                          female_male_student  female   male  \
# university_name
# Aalborg University                              [8363, 9059]    8363   9059
# Aalto University                               [5152, 10947]    5152  10947
# Aarhus University                             [12903, 10992]   12903  10992
# Aberystwyth University                          [4441, 4811]    4441   4811
# Adam Mickiewicz University                    [28849, 11784]   28849  11784
# ...                                                      ...     ...    ...
# École Normale Supérieure                        [1104, 1296]    1104   1296
# École Normale Supérieure de Lyon                [1087, 1131]    1087   1131
# École Polytechnique                              [437, 1992]     437   1992
# École Polytechnique Fédérale de Lausanne        [2610, 7056]    2610   7056
# Örebro University                               [5361, 3427]    5361   3427
#
#                                           fm_ratio
# university_name
# Aalborg University                        0.923077
# Aalto University                          0.470588
# Aarhus University                         1.173913
# Aberystwyth University                    0.923077
# Adam Mickiewicz University                2.448276
# ...                                            ...
# École Normale Supérieure                  0.851852
# École Normale Supérieure de Lyon          0.960784
# École Polytechnique                       0.219512
# École Polytechnique Fédérale de Lausanne  0.369863
# Örebro University                         1.564103
#
# [739 rows x 17 columns]

# %%
from statistics import harmonic_mean

# %% [markdown]
# for this task we compute the _average ratio_ using the harmonic mean because it is the index that best handles operations with ratios

# %%
average_ratio = harmonic_mean(times_max_year_clean['fm_ratio'])
print(average_ratio)
# Out:
# 0.7438791777857604

# %%
times_max_year_clean['avg_ratio'] = average_ratio
times_max_year_clean.head()
# Out:
#                            world_rank         country  teaching international  \
# university_name
# Aalborg University            201-250         Denmark      25.1          71.0
# Aalto University              251-300         Finland      31.1          65.4
# Aarhus University                =106         Denmark      36.9          76.8
# Aberystwyth University        301-350  United Kingdom      21.6          72.2
# Adam Mickiewicz University    601-800          Poland      20.0          25.7
#
#                             research  citations income total_score  \
# university_name
# Aalborg University              28.4       73.8   43.7           -
# Aalto University                32.8       62.1   61.6           -
# Aarhus University               50.7       79.8   68.3        57.7
# Aberystwyth University          18.9       67.2   31.3           -
# Adam Mickiewicz University      11.0       15.3   28.7           -
#
#                             num_students  student_staff_ratio  \
# university_name
# Aalborg University               17422.0                 15.9
# Aalto University                 16099.0                 24.2
# Aarhus University                23895.0                 13.6
# Aberystwyth University            9252.0                 19.2
# Adam Mickiewicz University       40633.0                 15.6
#
#                            international_students female_male_ratio  year  \
# university_name
# Aalborg University                            15%           48 : 52  2016
# Aalto University                              17%           32 : 68  2016
# Aarhus University                             14%           54 : 46  2016
# Aberystwyth University                        18%           48 : 52  2016
# Adam Mickiewicz University                     1%           71 : 29  2016
#
#                            female_male_student  female   male  fm_ratio  \
# university_name
# Aalborg University                [8363, 9059]    8363   9059  0.923077
# Aalto University                 [5152, 10947]    5152  10947  0.470588
# Aarhus University               [12903, 10992]   12903  10992  1.173913
# Aberystwyth University            [4441, 4811]    4441   4811  0.923077
# Adam Mickiewicz University      [28849, 11784]   28849  11784  2.448276
#
#                             avg_ratio
# university_name
# Aalborg University           0.743879
# Aalto University             0.743879
# Aarhus University            0.743879
# Aberystwyth University       0.743879
# Adam Mickiewicz University   0.743879

# %%
below_avg = times_max_year_clean[times_max_year_clean['fm_ratio'] < average_ratio][['world_rank', 'country', 'num_students', 'female_male_ratio', 'year', 'female', 'male', 'fm_ratio', 'avg_ratio']]
below_avg
# Out:
#                                          world_rank      country  \
# university_name
# Aalto University                            251-300      Finland
# Ajou University                             601-800  South Korea
# Aligarh Muslim University                   601-800        India
# Amirkabir University of Technology          501-600         Iran
# Andhra University                           601-800        India
# ...                                             ...          ...
# Yokohama National University                601-800        Japan
# Yıldız Technical University                 601-800       Turkey
# Zhejiang University                         251-300        China
# École Polytechnique                            =101       France
# École Polytechnique Fédérale de Lausanne         31  Switzerland
#
#                                           num_students female_male_ratio  \
# university_name
# Aalto University                               16099.0           32 : 68
# Ajou University                                12706.0           33 : 67
# Aligarh Muslim University                      11197.0           17 : 83
# Amirkabir University of Technology             14080.0           34 : 66
# Andhra University                              10407.0           36 : 64
# ...                                                ...               ...
# Yokohama National University                   10117.0           28 : 72
# Yıldız Technical University                    31268.0           36 : 64
# Zhejiang University                            47508.0           41 : 59
# École Polytechnique                             2429.0           18 : 82
# École Polytechnique Fédérale de Lausanne        9666.0           27 : 73
#
#                                           year  female   male  fm_ratio  \
# university_name
# Aalto University                          2016    5152  10947  0.470588
# Ajou University                           2016    4193   8513  0.492537
# Aligarh Muslim University                 2016    1903   9294  0.204819
# Amirkabir University of Technology        2016    4787   9293  0.515152
# Andhra University                         2016    3747   6660  0.562500
# ...                                        ...     ...    ...       ...
# Yokohama National University              2016    2833   7284  0.388889
# Yıldız Technical University               2016   11256  20012  0.562500
# Zhejiang University                       2016   19478  28030  0.694915
# École Polytechnique                       2016     437   1992  0.219512
# École Polytechnique Fédérale de Lausanne  2016    2610   7056  0.369863
#
#                                           avg_ratio
# university_name
# Aalto University                           0.743879
# Ajou University                            0.743879
# Aligarh Muslim University                  0.743879
# Amirkabir University of Technology         0.743879
# Andhra University                          0.743879
# ...                                             ...
# Yokohama National University               0.743879
# Yıldız Technical University                0.743879
# Zhejiang University                        0.743879
# École Polytechnique                        0.743879
# École Polytechnique Fédérale de Lausanne   0.743879
#
# [164 rows x 9 columns]

# %% [markdown]
# ## 7. For each country, compute the fraction of the students in the country that are in one of the universities computed in the previous point (that is, the denominator of the ratio is the total number of students over all universities in the country).

# %%
students_per_country.head()
# Out:
#             female    male  num_students
# country
# Argentina    67191   41182      108373.0
# Australia   391736  321640      713376.0
# Austria      68364   66113      134477.0
# Bangladesh   21323   41393       62716.0
# Belarus      20219    9084       29303.0

# %% [markdown]
# we considered at the denominator the total number of students over those universities in the country which had a non-missing _female_male_ratio_ value

# %%
students_below = below_avg.groupby('country')['num_students'].sum()
students_below.head()
# Out:
# country
# Austria        33961.0
# Bangladesh     62716.0
# Brazil          7741.0
# Chile          34457.0
# China         542991.0
# Name: num_students, dtype: float64

# %%
students_ratio = pd.merge(students_per_country, students_below, left_index = True, right_index = True, suffixes = ['_tot', '_below'], how = 'outer')
students_ratio
# Out:
#                            female     male  num_students_tot  \
# country
# Argentina                   67191    41182          108373.0
# Australia                  391736   321640          713376.0
# Austria                     68364    66113          134477.0
# Bangladesh                  21323    41393           62716.0
# Belarus                     20219     9084           29303.0
# ...                           ...      ...               ...
# Uganda                      18670    18670           37340.0
# Ukraine                     17846    19250           37096.0
# United Arab Emirates         9516     4931           14447.0
# United Kingdom             711815   613028         1324842.0
# United States of America  1601453  1556324         3157775.0
#
#                           num_students_below
# country
# Argentina                                NaN
# Australia                                NaN
# Austria                              33961.0
# Bangladesh                           62716.0
# Belarus                                  NaN
# ...                                      ...
# Uganda                                   NaN
# Ukraine                                  NaN
# United Arab Emirates                     NaN
# United Kingdom                       37784.0
# United States of America            192716.0
#
# [70 rows x 4 columns]

# %% [markdown]
# the missing values of the column _num_students_below_ will be filled with the digit value 0.0, because the missing value means that there aren't universities with _fm_ratio_ below the average ratio in that specific country

# %%
students_ratio['num_students_below'].fillna(0, inplace = True)
students_ratio.head()
# Out:
#             female    male  num_students_tot  num_students_below
# country
# Argentina    67191   41182          108373.0                 0.0
# Australia   391736  321640          713376.0                 0.0
# Austria      68364   66113          134477.0             33961.0
# Bangladesh   21323   41393           62716.0             62716.0
# Belarus      20219    9084           29303.0                 0.0

# %%
students_ratio['ratio'] = students_ratio['num_students_below'] / students_ratio['num_students_tot']
students_ratio
# Out:
#                            female     male  num_students_tot  \
# country
# Argentina                   67191    41182          108373.0
# Australia                  391736   321640          713376.0
# Austria                     68364    66113          134477.0
# Bangladesh                  21323    41393           62716.0
# Belarus                     20219     9084           29303.0
# ...                           ...      ...               ...
# Uganda                      18670    18670           37340.0
# Ukraine                     17846    19250           37096.0
# United Arab Emirates         9516     4931           14447.0
# United Kingdom             711815   613028         1324842.0
# United States of America  1601453  1556324         3157775.0
#
#                           num_students_below     ratio
# country
# Argentina                                0.0  0.000000
# Australia                                0.0  0.000000
# Austria                              33961.0  0.252541
# Bangladesh                           62716.0  1.000000
# Belarus                                  0.0  0.000000
# ...                                      ...       ...
# Uganda                                   0.0  0.000000
# Ukraine                                  0.0  0.000000
# United Arab Emirates                     0.0  0.000000
# United Kingdom                       37784.0  0.028520
# United States of America            192716.0  0.061029
#
# [70 rows x 5 columns]

# %% [markdown]
# ## 8. Read the file educational_attainment_supplementary_data.csv, discarding any row with missing country_name or series_name

# %%
edu = pd.read_csv(f'{data_folder}educational_attainment_supplementary_data.csv')
edu
# Out:
#                                             country_name  \
# 0                                            Afghanistan
# 1                                            Afghanistan
# 2                                            Afghanistan
# 3                                            Afghanistan
# 4                                            Afghanistan
# ...                                                  ...
# 79050                                                NaN
# 79051                                                NaN
# 79052                                                NaN
# 79053  Data from database: Education Statistics: Educ...
# 79054                           Last Updated: 10/20/2015
#
#                                              series_name  1985  1986  1987  \
# 0      Barro-Lee: Average years of primary schooling,...  0.33   NaN   NaN
# 1      Barro-Lee: Average years of primary schooling,...  1.03   NaN   NaN
# 2      Barro-Lee: Average years of primary schooling,...  0.83   NaN   NaN
# 3      Barro-Lee: Average years of primary schooling,...  2.34   NaN   NaN
# 4      Barro-Lee: Average years of primary schooling,...  0.54   NaN   NaN
# ...                                                  ...   ...   ...   ...
# 79050                                                NaN   NaN   NaN   NaN
# 79051                                                NaN   NaN   NaN   NaN
# 79052                                                NaN   NaN   NaN   NaN
# 79053                                                NaN   NaN   NaN   NaN
# 79054                                                NaN   NaN   NaN   NaN
#
#        1990  1991  1992  1993  1995  ...  2005  2006  2007  2008  2009  2010  \
# 0      0.44   NaN   NaN   NaN  0.57  ...  0.86   NaN   NaN   NaN   NaN  1.27
# 1      1.26   NaN   NaN   NaN  1.54  ...  2.18   NaN   NaN   NaN   NaN  2.64
# 2      0.95   NaN   NaN   NaN  1.26  ...  1.01   NaN   NaN   NaN   NaN  2.45
# 3      2.22   NaN   NaN   NaN  2.37  ...  2.26   NaN   NaN   NaN   NaN  3.55
# 4      0.92   NaN   NaN   NaN  0.94  ...  2.00   NaN   NaN   NaN   NaN  1.29
# ...     ...   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...   ...
# 79050   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 79051   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 79052   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 79053   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 79054   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#        2011  2012  2013  2015
# 0       NaN   NaN   NaN   NaN
# 1       NaN   NaN   NaN   NaN
# 2       NaN   NaN   NaN   NaN
# 3       NaN   NaN   NaN   NaN
# 4       NaN   NaN   NaN   NaN
# ...     ...   ...   ...   ...
# 79050   NaN   NaN   NaN   NaN
# 79051   NaN   NaN   NaN   NaN
# 79052   NaN   NaN   NaN   NaN
# 79053   NaN   NaN   NaN   NaN
# 79054   NaN   NaN   NaN   NaN
#
# [79055 rows x 29 columns]

# %%
edu.isnull().any()
# Out:
# country_name    True
# series_name     True
# 1985            True
# 1986            True
# 1987            True
# 1990            True
# 1991            True
# 1992            True
# 1993            True
# 1995            True
# 1996            True
# 1997            True
# 1998            True
# 1999            True
# 2000            True
# 2001            True
# 2002            True
# 2003            True
# 2004            True
# 2005            True
# 2006            True
# 2007            True
# 2008            True
# 2009            True
# 2010            True
# 2011            True
# 2012            True
# 2013            True
# 2015            True
# dtype: bool

# %%
edu.dropna(subset = ['country_name', 'series_name'], inplace = True)
edu.head() #rivedere se possibile farlo nella read_csv
# Out:
#   country_name                                        series_name  1985  1986  \
# 0  Afghanistan  Barro-Lee: Average years of primary schooling,...  0.33   NaN
# 1  Afghanistan  Barro-Lee: Average years of primary schooling,...  1.03   NaN
# 2  Afghanistan  Barro-Lee: Average years of primary schooling,...  0.83   NaN
# 3  Afghanistan  Barro-Lee: Average years of primary schooling,...  2.34   NaN
# 4  Afghanistan  Barro-Lee: Average years of primary schooling,...  0.54   NaN
#
#    1987  1990  1991  1992  1993  1995  ...  2005  2006  2007  2008  2009  \
# 0   NaN  0.44   NaN   NaN   NaN  0.57  ...  0.86   NaN   NaN   NaN   NaN
# 1   NaN  1.26   NaN   NaN   NaN  1.54  ...  2.18   NaN   NaN   NaN   NaN
# 2   NaN  0.95   NaN   NaN   NaN  1.26  ...  1.01   NaN   NaN   NaN   NaN
# 3   NaN  2.22   NaN   NaN   NaN  2.37  ...  2.26   NaN   NaN   NaN   NaN
# 4   NaN  0.92   NaN   NaN   NaN  0.94  ...  2.00   NaN   NaN   NaN   NaN
#
#    2010  2011  2012  2013  2015
# 0  1.27   NaN   NaN   NaN   NaN
# 1  2.64   NaN   NaN   NaN   NaN
# 2  2.45   NaN   NaN   NaN   NaN
# 3  3.55   NaN   NaN   NaN   NaN
# 4  1.29   NaN   NaN   NaN   NaN
#
# [5 rows x 29 columns]

# %%
edu.notnull().any()
# Out:
# country_name     True
# series_name      True
# 1985             True
# 1986             True
# 1987             True
# 1990             True
# 1991             True
# 1992             True
# 1993             True
# 1995             True
# 1996             True
# 1997            False
# 1998             True
# 1999             True
# 2000             True
# 2001             True
# 2002             True
# 2003             True
# 2004             True
# 2005             True
# 2006             True
# 2007             True
# 2008             True
# 2009             True
# 2010             True
# 2011             True
# 2012             True
# 2013             True
# 2015            False
# dtype: bool

# %%
edu.isnull().any().head()
# Out:
# country_name    False
# series_name     False
# 1985             True
# 1986             True
# 1987             True
# dtype: bool

# %% [markdown]
# ## 9. From attainment build a dataframe with the same data, but with 4 columns: country_name, series_name, year, value

# %%
edu_melted = edu.melt(id_vars = ['country_name','series_name'], var_name = 'year')
edu_melted
# Out:
#         country_name                                        series_name  year  \
# 0        Afghanistan  Barro-Lee: Average years of primary schooling,...  1985
# 1        Afghanistan  Barro-Lee: Average years of primary schooling,...  1985
# 2        Afghanistan  Barro-Lee: Average years of primary schooling,...  1985
# 3        Afghanistan  Barro-Lee: Average years of primary schooling,...  1985
# 4        Afghanistan  Barro-Lee: Average years of primary schooling,...  1985
# ...              ...                                                ...   ...
# 2134345     Zimbabwe  UIS: Percentage of population age 25+ with som...  2015
# 2134346     Zimbabwe  UIS: Percentage of population age 25+ with som...  2015
# 2134347     Zimbabwe  UIS: Percentage of population age 25+ with unk...  2015
# 2134348     Zimbabwe  UIS: Percentage of population age 25+ with unk...  2015
# 2134349     Zimbabwe  UIS: Percentage of population age 25+ with unk...  2015
#
#          value
# 0         0.33
# 1         1.03
# 2         0.83
# 3         2.34
# 4         0.54
# ...        ...
# 2134345    NaN
# 2134346    NaN
# 2134347    NaN
# 2134348    NaN
# 2134349    NaN
#
# [2134350 rows x 4 columns]

# %%
edu_melted.dropna(subset = ['value'], inplace = True)
edu_melted
# Out:
#                country_name  \
# 0               Afghanistan
# 1               Afghanistan
# 2               Afghanistan
# 3               Afghanistan
# 4               Afghanistan
# ...                     ...
# 2054020  West Bank and Gaza
# 2054021  West Bank and Gaza
# 2054022  West Bank and Gaza
# 2054023  West Bank and Gaza
# 2054024  West Bank and Gaza
#
#                                                series_name  year    value
# 0        Barro-Lee: Average years of primary schooling,...  1985  0.33000
# 1        Barro-Lee: Average years of primary schooling,...  1985  1.03000
# 2        Barro-Lee: Average years of primary schooling,...  1985  0.83000
# 3        Barro-Lee: Average years of primary schooling,...  1985  2.34000
# 4        Barro-Lee: Average years of primary schooling,...  1985  0.54000
# ...                                                    ...   ...      ...
# 2054020  UIS: Percentage of population age 25+ with som...  2013  1.48356
# 2054021  UIS: Percentage of population age 25+ with som...  2013  1.88820
# 2054022  UIS: Percentage of population age 25+ with unk...  2013  0.00000
# 2054023  UIS: Percentage of population age 25+ with unk...  2013  0.00000
# 2054024  UIS: Percentage of population age 25+ with unk...  2013  0.00000
#
# [318290 rows x 4 columns]

# %% [markdown]
# ## 10. For each university, find the number of rankings in which they appear (it suffices to appear in one year for each ranking).

# %%
times_unique_uni = pd.DataFrame(times['university_name'].unique(), columns = ['university'])
times_unique_uni
# Out:
#                                 university
# 0                       Harvard University
# 1       California Institute of Technology
# 2    Massachusetts Institute of Technology
# 3                      Stanford University
# 4                     Princeton University
# ..                                     ...
# 813                      Xidian University
# 814                    Yeungnam University
# 815            Yıldız Technical University
# 816               Yokohama City University
# 817           Yokohama National University
#
# [818 rows x 1 columns]

# %%
shanghai_unique_uni = pd.DataFrame(shanghai['university_name'].unique(), columns = ['university'])
shanghai_unique_uni
# Out:
#                                       university
# 0                             Harvard University
# 1                        University of Cambridge
# 2                            Stanford University
# 3             University of California, Berkeley
# 4    Massachusetts Institute of Technology (MIT)
# ..                                           ...
# 653                   Capital Medical University
# 654          Queensland University of Technology
# 655              Sharif University of Technology
# 656                          University of Genoa
# 657                        University of Seville
#
# [658 rows x 1 columns]

# %%
cwur_unique_uni = pd.DataFrame(cwur['institution'].unique(), columns = ['university'])
cwur_unique_uni
# Out:
#                                  university
# 0                        Harvard University
# 1     Massachusetts Institute of Technology
# 2                       Stanford University
# 3                   University of Cambridge
# 4        California Institute of Technology
# ...                                     ...
# 1019                    Shenzhen University
# 1020             Tianjin Medical University
# 1021                Babeș-Bolyai University
# 1022                Henan Normal University
# 1023          Southwest Jiaotong University
#
# [1024 rows x 1 columns]

# %%
uni_concat = pd.concat([times_unique_uni, shanghai_unique_uni, cwur_unique_uni], ignore_index = True)
uni_concat
# Out:
#                                  university
# 0                        Harvard University
# 1        California Institute of Technology
# 2     Massachusetts Institute of Technology
# 3                       Stanford University
# 4                      Princeton University
# ...                                     ...
# 2495                    Shenzhen University
# 2496             Tianjin Medical University
# 2497                Babeș-Bolyai University
# 2498                Henan Normal University
# 2499          Southwest Jiaotong University
#
# [2500 rows x 1 columns]

# %%
uni_concat[uni_concat['university'].isnull()]
# Out:
# Empty DataFrame
# Columns: [university]
# Index: []

# %%
number_rankings = uni_concat.groupby('university', as_index = False).size()
number_rankings
# Out:
#                                     university  size
# 0     AGH University of Science and Technology     2
# 1                           Aalborg University     3
# 2                             Aalto University     3
# 3                            Aarhus University     3
# 4                       Aberystwyth University     2
# ...                                        ...   ...
# 1447                    École centrale de Lyon     1
# 1448          École normale supérieure - Paris     1
# 1449        École normale supérieure de Cachan     1
# 1450          École normale supérieure de Lyon     1
# 1451                         Örebro University     2
#
# [1452 rows x 2 columns]

# %%
number_rankings[(number_rankings['size'] > 3) | (number_rankings['size'] < 1)]
# Out:
# Empty DataFrame
# Columns: [university, size]
# Index: []

# %% [markdown]
# ## 11. In the times ranking, compute the number of times each university appears

# %% [markdown]
# ## 12. Find the universities that appear at most twice in the times ranking.

# %% [markdown]
# ## 13. The universities that, in any year, have the same position in all three rankings (they must have the same position in a year).
